# %%
import pandas as pd

# %%
series = pd.read_csv("data\google_stock_price.csv", usecols=["Price"]).squeeze("columns")

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series
# Out:
# 0         2.490664
# 1         2.515820
# 2         2.758411
# 3         2.770615
# 4         2.614201
#            ...
# 4788    132.080002
# 4789    132.998001
# 4790    135.570007
# 4791    137.050003
# 4792    138.429993
# Name: Price, Length: 4793, dtype: float64

# %%
series.head()
# Out:
# 0    2.490664
# 1    2.515820
# 2    2.758411
# 3    2.770615
# 4    2.614201
# Name: Price, dtype: float64

# %%
series.tail()
# Out:
# 4788    132.080002
# 4789    132.998001
# 4790    135.570007
# 4791    137.050003
# 4792    138.429993
# Name: Price, dtype: float64
