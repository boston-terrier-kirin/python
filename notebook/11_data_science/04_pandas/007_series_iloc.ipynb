# %%
import pandas as pd

# %%
df = pd.read_csv("data\pokemon.csv")

# %%
pokemon = df["Name"]

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Name, dtype: object

# %%
# ilocはsliceができる
pokemon.iloc[0:5]
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Name, dtype: object
