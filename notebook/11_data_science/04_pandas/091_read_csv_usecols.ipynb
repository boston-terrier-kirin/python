# %%
import pandas as pd

# %%
df = pd.read_csv("data\pokemon.csv")

# %%
df.head()
# Out:
#          Name           Type
# 0   Bulbasaur  Grass, Poison
# 1     Ivysaur  Grass, Poison
# 2    Venusaur  Grass, Poison
# 3  Charmander           Fire
# 4  Charmeleon           Fire

# %%
df = pd.read_csv("data\pokemon.csv", usecols=["Name"])

# %%
df.head()
# Out:
#          Name
# 0   Bulbasaur
# 1     Ivysaur
# 2    Venusaur
# 3  Charmander
# 4  Charmeleon
