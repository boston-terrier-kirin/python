# %%
import pandas as pd
btc = pd.read_csv("coin_Bitcoin.csv")
countries = pd.read_csv("world-happiness-report-2021.csv")
houses = pd.read_csv("kc_house_data.csv")
titanic = pd.read_csv("titanic.csv")
netflix = pd.read_csv("netflix_titles.csv", sep="|")

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.insert(7, "num_relatives", titanic["sibsp"] + titanic["parch"])

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  num_relatives  ticket      fare    cabin embarked  \
# 0      29      0      0              0   24160  211.3375       B5        S
# 1  0.9167      1      2              3  113781    151.55  C22 C26        S
# 2       2      1      2              3  113781    151.55  C22 C26        S
# 3      30      1      2              3  113781    151.55  C22 C26        S
# 4      25      1      2              3  113781    151.55  C22 C26        S
#
#   boat body                        home.dest
# 0    2    ?                     St Louis, MO
# 1   11    ?  Montreal, PQ / Chesterville, ON
# 2    ?    ?  Montreal, PQ / Chesterville, ON
# 3    ?  135  Montreal, PQ / Chesterville, ON
# 4    ?    ?  Montreal, PQ / Chesterville, ON

# %%
titanic.sort_values("num_relatives", ascending=False).head()
# Out:
#       pclass  survived                          name     sex age  sibsp  \
# 1177       3         0           Sage, Mr. Frederick    male   ?      8
# 1179       3         0         Sage, Mr. John George    male   ?      1
# 1173       3         0  Sage, Miss. Constance Gladys  female   ?      8
# 1170       3         0    Sage, Master. Thomas Henry    male   ?      8
# 1172       3         0               Sage, Miss. Ada  female   ?      8
#
#       parch  num_relatives    ticket   fare cabin embarked boat body home.dest
# 1177      2             10  CA. 2343  69.55     ?        S    ?    ?         ?
# 1179      9             10  CA. 2343  69.55     ?        S    ?    ?         ?
# 1173      2             10  CA. 2343  69.55     ?        S    ?    ?         ?
# 1170      2             10  CA. 2343  69.55     ?        S    ?    ?         ?
# 1172      2             10  CA. 2343  69.55     ?        S    ?    ?         ?
