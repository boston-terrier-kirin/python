# %%
import pandas as pd

# %%
pd.to_datetime("2024/4/21 9:45")
# Out:
# Timestamp('2024-04-21 09:45:00')

# %% [markdown]
# # format指定

# %%
pd.to_datetime("10/11/12")
# Out:
# Timestamp('2012-10-11 00:00:00')

# %%
pd.to_datetime("10/11/12", yearfirst=True, dayfirst=True)
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
pd.to_datetime("10/11/12", yearfirst=True, dayfirst=False)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %% [markdown]
# ## https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
pd.to_datetime("10/11/12", format="%y/%m/%d")
# Out:
# Timestamp('2010-11-12 00:00:00')

# %% [markdown]
# ## with dataset

# %%
ufos = pd.read_csv("nuforc_reports.csv")

# %%
ufos.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#              date_time     shape     duration  \
# 0  2019-12-12T18:43:00     light    5 seconds
# 1  2019-03-22T18:30:00    circle  3-5 seconds
# 2                  NaN       NaN          NaN
# 3  2019-04-17T02:00:00  teardrop   10 seconds
# 4  2009-03-15T18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         5 non-null      object
#  1   city            4 non-null      object
#  2   state           4 non-null      object
#  3   date_time       4 non-null      object
#  4   shape           4 non-null      object
#  5   duration        4 non-null      object
#  6   stats           5 non-null      object
#  7   report_link     5 non-null      object
#  8   text            5 non-null      object
#  9   posted          4 non-null      object
#  10  city_latitude   3 non-null      float64
#  11  city_longitude  3 non-null      float64
# dtypes: float64(2), object(10)
# memory usage: 608.0+ bytes

# %% [markdown]
# ### date_timeを変換

# %%
ufos["date_time"] = pd.to_datetime(ufos["date_time"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         19 non-null     object
#  1   city            18 non-null     object
#  2   state           17 non-null     object
#  3   date_time       18 non-null     datetime64[ns]
#  4   shape           18 non-null     object
#  5   duration        18 non-null     object
#  6   stats           19 non-null     object
#  7   report_link     19 non-null     object
#  8   text            19 non-null     object
#  9   posted          18 non-null     object
#  10  city_latitude   15 non-null     float64
#  11  city_longitude  15 non-null     float64
#  12  date            18 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 2.1+ KB

# %%
ufos.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %% [markdown]
# ### parse_dates

# %%
ufos = pd.read_csv("nuforc_reports.csv", parse_dates=["date_time"])

# %%
ufos.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...
