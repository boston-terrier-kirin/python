# %% [markdown]
# # floatの比較は注意が必要

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %% [markdown]
# ### 0.1は0.1ではない

# %%
format(0.1, ".25f")
# Out:
# '0.1000000000000000055511151'

# %%
format(0.625, ".25f")
# Out:
# '0.6250000000000000000000000'
